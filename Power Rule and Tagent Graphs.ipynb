# %% [markdown]
# # Power Rule in Differentiation
#
# ## Introduction
#
# The power rule is one of the most commonly used rules in differentiation. It provides a straightforward way to find the derivative of functions of the form $f(x) = x^n$, where $n$ is any real number.
#
# ## Power Rule
#
# The power rule states that if $f(x) = x^n$, where $n$ is a real number, then the derivative of $f(x)$ with respect to $x$ is:
#
# $$
# f'(x) = nx^{n-1}
# $$
#
# This rule simplifies the process of finding derivatives of polynomial functions and functions with fractional or negative exponents.
#
# ## Easy Examples
#
# ### Example 1: $f(x) = x^2$
#
# Apply the power rule with $n = 2$:
#
# $$
# f(x) = x^2
# $$
#
# Using the power rule:
#
# $$
# f'(x) = 2x^{2-1} = 2x
# $$
#
# ### Example 2: $f(x) = 2x^2$
#
# Apply the power rule with $n = 2$ and multiply by the constant coefficient 2:
#
# $$
# f(x) = 2x^2
# $$
#
# Using the power rule:
#
# $$
# f'(x) = 2 \cdot 2x^{2-1} = 4x
# $$
#
# ## Intermediate Examples
#
# ### Example 3: $f(x) = x^{1/2}$
#
# Apply the power rule with $n = 1/2$:
#
# $$
# f(x) = x^{1/2}
# $$
#
# Using the power rule:
#
# $$
# f'(x) = \frac{1}{2} x^{1/2 - 1} = \frac{1}{2} x^{-1/2}
# $$
#
# ### Example 4: $f(x) = x^{-1/2}$
#
# Apply the power rule with $n = -1/2$:
#
# $$
# f(x) = x^{-1/2}
# $$
#
# Using the power rule:
#
# $$
# f'(x) = -\frac{1}{2} x^{-1/2 - 1} = -\frac{1}{2} x^{-3/2}
# $$
#
# ## Advanced Examples
#
# ### Example 5: $f(x) = 4x^4$
#
# Apply the power rule with $n = 4$ and multiply by the constant coefficient 4:
#
# $$
# f(x) = 4x^4
# $$
#
# Using the power rule:
#
# $$
# f'(x) = 4 \cdot 4x^{4-1} = 16x^3
# $$
#
# ### Example 6: $f(x) = 3x^{-1/3}$
#
# Apply the power rule with $n = -1/3$ and multiply by the constant coefficient 3:
#
# $$
# f(x) = 3x^{-1/3}
# $$
#
# Using the power rule:
#
# $$
# f'(x) = 3 \cdot \left(-\frac{1}{3}\right)x^{-1/3 - 1} = -x^{-4/3}
# $$
#
# ## Conclusion
#
# The power rule is a fundamental tool in differentiation that allows us to easily find the derivatives of functions of the form $x^n$. Here are the key steps to apply the power rule:
# 1. Identify the exponent $n$ in the function $x^n$.
# 2. Multiply by the exponent $n$.
# 3. Subtract 1 from the exponent to find the new exponent.
#
# Using these steps, we can quickly and efficiently find the derivatives of a wide variety of functions. Here are some examples:
#
# - For $f(x) = x^2$, the derivative is $f'(x) = 2x$.
# - For $f(x) = 2x^2$, the derivative is $f'(x) = 4x$.
# - For $f(x) = x^{1/2}$, the derivative is $f'(x) = \frac{1}{2} x^{-1/2}$.
# - For $f(x) = x^{-1/2}$, the derivative is $f'(x) = -\frac{1}{2} x^{-3/2}$.
# - For $f(x) = 4x^4$, the derivative is $f'(x) = 16x^3$.
# - For $f(x) = 3x^{-1/3}$, the derivative is $f'(x) = -x^{-4/3}$.
#
# Understanding and applying the power rule is essential for solving many problems in calculus and related fields.

# %% [markdown]
# # Exercise Questions on Power Rule in Differentiation
#
# ## Question 1
#
# Differentiate the following function using the power rule:
#
# $$
# f(x) = 5x^3
# $$
#
# ## Question 2
#
# Find the derivative of the function:
#
# $$
# f(x) = \frac{1}{2}x^{2.5}
# $$
#
# ## Question 3
#
# Differentiate the following function using the power rule:
#
# $$
# f(x) = 7x^{-2}
# $$
#
# ## Question 4
#
# Find the derivative of the function:
#
# $$
# f(x) = -4x^{1/3}
# $$
#
# ## Question 5
#
# Differentiate the following function using the power rule:
#
# $$
# f(x) = \frac{3}{4}x^{-5/2}
# $$
#
# ## Solutions
#
# ### Solution 1
#
# For the function $ f(x) = 5x^3 $:
#
# Apply the power rule with $ n = 3 $:
#
# $$
# f'(x) = 5 \cdot 3x^{3-1} = 15x^2
# $$
#
# ### Solution 2
#
# For the function $ f(x) = \frac{1}{2}x^{2.5} $:
#
# Apply the power rule with $ n = 2.5 $:
#
# $$
# f'(x) = \frac{1}{2} \cdot 2.5x^{2.5-1} = \frac{5}{4}x^{1.5}
# $$
#
# ### Solution 3
#
# For the function $ f(x) = 7x^{-2} $:
#
# Apply the power rule with $ n = -2 $:
#
# $$
# f'(x) = 7 \cdot (-2)x^{-2-1} = -14x^{-3} = \frac{-14}{x^3}
# $$
#
# ### Solution 4
#
# For the function $ f(x) = -4x^{1/3} $:
#
# Apply the power rule with $ n = 1/3 $:
#
# $$
# f'(x) = -4 \cdot \frac{1}{3}x^{1/3-1} = -\frac{4}{3}x^{-2/3}
# $$
#
# ### Solution 5
#
# For the function $ f(x) = \frac{3}{4}x^{-5/2} + 3 $:
#
# The derivative of a constant = 0 so $f'(x) [3] = 0$
#
# Apply the power rule with $ n = -5/2 $:
#
# $$
# f'(x) = \frac{3}{4} \cdot \left(-\frac{5}{2}\right)x^{-5/2-1} = -\frac{15}{8}x^{-7/2}
# $$

# %% [markdown]
# # Examples
#
# ## Introduction
#
# ### Example 1
#
# Find a point on the curve $y = 2 - \sqrt{x}$ where the slope is $-0.5$.
#
# ![image.png](attachment:image.png)
#
# ### Solution
#
# Ee need to determine the $x$-coordinate where the derivative of the function equals $-0.5$. Once we find the $x$-coordinate, we can substitute it back into the original function to find the corresponding $y$-coordinate.
#
# ## Function and Derivative
#
# Given the function:
#
# $$
# f(x) = 2 - \sqrt{x}
# $$
#
# To find the derivative, we first rewrite the function in a form suitable for applying the power rule:
#
# $$
# f(x) = 2 - x^{1/2}
# $$
#
# Using the power rule, the derivative of $x^{1/2}$ is:
#
# $$
# \frac{d}{dx} x^{1/2} = \frac{1}{2} x^{-1/2} = \frac{1}{2\sqrt{x}}
# $$
#
# Therefore, the derivative of $f(x)$ is:
#
# $$
# f'(x) = -\frac{1}{2} x^{-1/2} = -\frac{1}{2\sqrt{x}}
# $$
#
# ## Finding the $x$-coordinate Where the Slope is $-0.5$
#
# We set the derivative equal to $-0.5$ and solve for $x$:
#
# $$
# -\frac{1}{2\sqrt{x}} = -0.5
# $$
#
# First, remove the negative sign:
#
# $$
# \frac{1}{2\sqrt{x}} = 0.5
# $$
#
# Next, multiply both sides by $2\sqrt{x}$:
#
# $$
# 1 = 2\sqrt{x} \cdot 0.5
# $$
#
# $$
# 1 = \sqrt{x}
# $$
#
# Square both sides to solve for $x$:
#
# $$
# 1^2 = (\sqrt{x})^2
# $$
#
# $$
# x = 1
# $$
#
# ## Finding the Corresponding $y$-coordinate
#
# Substitute $x = 1$ back into the original function to find $y$:
#
# $$
# y = 2 - \sqrt{1}
# $$
#
# $$
# y = 2 - 1
# $$
#
# $$
# y = 1
# $$
#
# ## Conclusion
#
# The point on the curve $y = 2 - \sqrt{x}$ where the slope is $-0.5$ is $(1, 1)$.

# %% [markdown]
# ## Example 2
#
#
#
#
#
# Find the point on the curve $y = \frac{x^3}{2} + 2$ where the slope is $0.4$,
#
# ![image.png](attachment:image.png)
#
# ## Answer
#
# We need to determine the $x$-coordinate where the derivative of the function equals $0.4$.Once we find the $x$-coordinate, we can substitute it back into the original function to find the corresponding $y$-coordinate.
#
# ## Function and Derivative
#
# Given the function:
#
# $$
# f(x) = \frac{x^3}{2} + 2
# $$
#
# To find the derivative, we use the power rule:
#
# $$
# f'(x) = \frac{d}{dx} \left( \frac{x^3}{2} \right) + \frac{d}{dx}(2)
# $$
#
# Since the derivative of a constant is zero, we get:
#
# $$
# f'(x) = \frac{3}{2} x^2
# $$
#
# ## Finding the $x$-coordinate Where the Slope is $0.4$
#
# We need to determine the $x$-coordinate where the derivative of the function equals $0.4$. Once we find the $x$-coordinate, we can substitute it back into the original function to find the corresponding $y$-coordinate.
#
# ## Function and Derivative
#
# Given the function:
#
# $$
# f(x) = \frac{x^3}{2} + 2
# $$
#
# To find the derivative, we use the power rule:
#
# $$
# f'(x) = \frac{d}{dx} \left( \frac{x^3}{2} \right) + \frac{d}{dx}(2)
# $$
#
# Since the derivative of a constant is zero, we get:
#
# $$
# f'(x) = \frac{3}{2} x^2
# $$
#
# ## Finding the $x$-coordinate Where the Slope is $0.4$
#
# We set the derivative equal to $0.4$ and solve for $x$:
#
# $$
# \frac{3}{2} x^2 = 0.4
# $$
#
# First, multiply both sides by $\frac{2}{3}$ to isolate $x^2$:
#
# $$
# x^2 = \frac{0.4 \times 2}{3} = \frac{0.8}{3} = \frac{4}{15}
# $$
#
# Next, take the square root of both sides to solve for $x$:
#
# $$
# x = \pm \sqrt{\frac{4}{15}} = \pm \frac{2}{\sqrt{15}} = \pm \frac{2 \sqrt{15}}{15}
# $$
#
# $$
# x = \pm 0.516
# $$
#
# ## Finding the Corresponding $y$-coordinate
#
# Substitute $x = 0.516$ back into the original function to find $y$:
#
# $$
# y = \frac{(0.516)^3}{2} + 2
# $$
#
# Simplify the expression:
#
# $$
# y = \frac{0.137}{2} + 2
# $$
#
# $$
# y = 0.0684 + 2
# $$
#
# $$
# y = 2.07
# $$
#
# Similarly, substitute $x = -0.516$ back into the original function to find $y$:
#
# $$
# y = \frac{(-0.516)^3}{2} + 2
# $$
#
# Simplify the expression:
#
# $$
# y = \frac{-0.137}{2} + 2
# $$
#
# $$
# y = -0.0684 + 2
# $$
#
# $$
# y = 1.93
# $$
#
# ## Conclusion
#
# The points on the curve $y = \frac{x^3}{2} + 2$ where the slope is $0.4$ are approximately:
#
# $$
# \left( 0.516, 2.07 \right)
# $$
#
# and
#
# $$
# \left( -0.516, 1.93 \right)
# $$

# %% [markdown]
# # Practice Questions
#
# ## Question 1
#
# Find the point on the curve $y = 2\sqrt{x}$ where the slope is $1.4$.
#
# ## Question 2
#
# Find the point on the curve $y = 3x^2 + x^2 + 3$ where the slope is $1$.
#
# ## Question 3
#
# Find the point on the curve $y = \frac{x^3}{3} + 3x^2 - 2x + 1$ where the slope is $2$.

# %% [markdown]
# # Solving Practice Questions Using Power Rule
#
# ## Question 1
#
# Find the point on the curve $y = 2\sqrt{x}$ where the slope is $1.4$.
#
# 1. **Rewrite the function in a more convenient form:**
#
#    $$
#    y = 2x^{1/2}
#    $$
#
# 2. **Differentiate the function using the power rule:**
#
#    $$
#    \frac{dy}{dx} = 2 \cdot \frac{1}{2} x^{-1/2} = x^{-1/2} = \frac{1}{\sqrt{x}}
#    $$
#
# 3. **Set the derivative equal to $1.4$ and solve for $x$:**
#
#    $$
#    \frac{1}{\sqrt{x}} = 1.4
#    $$
#
#    $$
#    \sqrt{x} = \frac{1}{1.4} = \frac{5}{7}
#    $$
#
#    $$
#    x = \left(\frac{5}{7}\right)^2 = \frac{25}{49}
#    $$
#
# 4. **Find the corresponding $y$-coordinate by substituting $x = \frac{25}{49}$ back into the original function:**
#
#    $$
#    y = 2\sqrt{\frac{25}{49}} = 2 \cdot \frac{5}{7} = \frac{10}{7}
#    $$
#
# 5. **Conclusion:**
#
#    The point on the curve $y = 2\sqrt{x}$ where the slope is $1.4$ is:
#
#    $$
#    \left( \frac{25}{49}, \frac{10}{7} \right)
#    $$
#
# ## Question 2
#
# Find the point on the curve $y = 3x^2 + x^2 + 3$ where the slope is $1$.
#
# 1. **Simplify the function:**
#
#    $$
#    y = 4x^2 + 3
#    $$
#
# 2. **Differentiate the function using the power rule:**
#
#    $$
#    \frac{dy}{dx} = 8x
#    $$
#
# 3. **Set the derivative equal to $1$ and solve for $x$:**
#
#    $$
#    8x = 1
#    $$
#
#    $$
#    x = \frac{1}{8}
#    $$
#
# 4. **Find the corresponding $y$-coordinate by substituting $x = \frac{1}{8}$ back into the original function:**
#
#    $$
#    y = 4\left( \frac{1}{8} \right)^2 + 3 = 4 \cdot \frac{1}{64} + 3 = \frac{1}{16} + 3 = \frac{1}{16} + \frac{48}{16} = \frac{49}{16}
#    $$
#
# 5. **Conclusion:**
#
#    The point on the curve $y = 3x^2 + x^2 + 3$ where the slope is $1$ is:
#
#    $$
#    \left( \frac{1}{8}, \frac{49}{16} \right)
#    $$
#
# ## Question 3
#
# Find the point on the curve $y = \frac{x^3}{3} + 3x^2 - 2x + 1$ where the slope is $2$.
#
# 1. **Differentiate the function using the power rule:**
#
#    $$
#    \frac{dy}{dx} = x^2 + 6x - 2
#    $$
#
# 2. **Set the derivative equal to $2$ and solve for $x$:**
#
#    $$
#    x^2 + 6x - 2 = 2
#    $$
#
#    $$
#    x^2 + 6x - 4 = 0
#    $$
#
# 3. **Solve the quadratic equation $x^2 + 6x - 4 = 0$:**
#
#    $$
#    x = \frac{-b \pm \sqrt{b^2 - 4ac}}{2a} = \frac{-6 \pm \sqrt{36 + 16}}{2} = \frac{-6 \pm \sqrt{52}}{2} = \frac{-6 \pm 2\sqrt{13}}{2} = -3 \pm \sqrt{13}
#    $$
#
#    Approximations:
#
#    $$
#    x_1 \approx -3 + 3.606 \approx 0.606
#    $$
#
#    $$
#    x_2 \approx -3 - 3.606 \approx -6.606
#    $$
#
# 4. **Find the corresponding $y$-coordinates by substituting $x_1 \approx 0.606$ and $x_2 \approx -6.606$ back into the original function:**
#
#    For $x_1 \approx 0.606$:
#
#    $$
#    y = \frac{(0.606)^3}{3} + 3(0.606)^2 - 2(0.606) + 1 \approx 0.963
#    $$
#
#    For $x_2 \approx -6.606$:
#
#    $$
#    y = \frac{(-6.606)^3}{3} + 3(-6.606)^2 - 2(-6.606) + 1 \approx 49.855
#    $$
#
# 5. **Conclusion:**
#
#    The points on the curve $y = \frac{x^3}{3} + 3x^2 - 2x + 1$ where the slope is $2$ are approximately:
#
#    $$
#    (0.606, 0.963)
#    $$
#
#    and
#
#    $$
#    (-6.606, 49.855)
#    $$

# %% [markdown]
# # Finding Equations of Tangent Lines to Curves at Particular Points
#
# ## Introduction
#
# The equation of a tangent line to a curve at a particular point can be found using the derivative of the function. The tangent line at a point $(a, f(a))$ has the same slope as the derivative of the function at that point. The general form of the tangent line equation is:
#
# $$y - y_1 = m(x - x_1)$$
#
# $$
# y - f(a) = f'(a)(x - a)
# $$
#
# ## Example 1: $y = x^{1/2}$ at $x = 2$
#
# ### Step 1: Find the derivative of the function
#
# Given the function:
#
# $$
# f(x) = x^{1/2}
# $$
#
# We find the derivative using the power rule:
#
# $$
# f'(x) = \frac{1}{2} x^{1/2 - 1} = \frac{1}{2} x^{-1/2}
# $$
#
# ### Step 2: Evaluate the derivative at $x = 2$
#
# To find the slope of the tangent line at $x = 2$:
#
# $$
# f'(2) = \frac{1}{2} \cdot 2^{-1/2} = \frac{1}{2\sqrt{2}} = \frac{1}{2\sqrt{2}} = \frac{1}{2\sqrt{2}} \cdot \frac{\sqrt{2}}{\sqrt{2}} = \frac{\sqrt{2}}{4}
# $$
#
# ### Step 3: Find the value of the function at $x = 2$
#
# To find the point on the curve:
#
# $$
# f(2) = 2^{1/2} = \sqrt{2}
# $$
#
# The point of tangency is $(2, \sqrt{2})$.
#
# ### Step 4: Write the equation of the tangent line
#
# Using the point-slope form of the line:
#
# $$
# y - f(a) = f'(a)(x - a)
# $$
#
# Substitute $a = 2$, $f(a) = \sqrt{2}$, and $f'(a) = \frac{\sqrt{2}}{4}$:
#
# $$
# y - \sqrt{2} = \frac{\sqrt{2}}{4}(x - 2)
# $$
#
# Simplify:
#
# $$
# y = \frac{\sqrt{2}}{4}x - \frac{\sqrt{2}}{4} \cdot 2 + \sqrt{2}
# $$
#
# $$
# y = \frac{\sqrt{2}}{4}x - \frac{\sqrt{2}}{2} + \sqrt{2}
# $$
#
# $$
# y = \frac{\sqrt{2}}{4}x + \frac{\sqrt{2}}{2}
# $$
#
# So, the equation of the tangent line to the curve $y = x^{1/2}$ at $x = 2$ is:
#
# $$
# y = \frac{\sqrt{2}}{4}x + \frac{\sqrt{2}}{2}
# $$
#
# ![image.png](attachment:image.png)
#
# ## Example 2: $y = 4x^3$ at $x = 0.5$
#
# ### Step 1: Find the derivative of the function
#
# Given the function:
#
# $$
# f(x) = 4x^3
# $$
#
# We find the derivative using the power rule:
#
# $$
# f'(x) = 4 \cdot 3x^{3-1} = 12x^2
# $$
#
# ### Step 2: Evaluate the derivative at $x = 0.5$
#
# To find the slope of the tangent line at $x = 0.5$:
#
# $$
# f'(0.5) = 12 \cdot (0.5)^2 = 12 \cdot 0.25 = 3
# $$
#
# ### Step 3: Find the value of the function at $x = 0.5$
#
# To find the point on the curve:
#
# $$
# f(0.5) = 4 \cdot (0.5)^3 = 4 \cdot 0.125 = 0.5
# $$
#
# The point of tangency is $(0.5, 0.5)$.
#
# ### Step 4: Write the equation of the tangent line
#
# Using the point-slope form of the line:
#
# $$
# y - f(a) = f'(a)(x - a)
# $$
#
# Substitute $a = 0.5$, $f(a) = 0.5$, and $f'(a) = 3$:
#
# $$
# y - 0.5 = 3(x - 0.5)
# $$
#
# Simplify:
#
# $$
# y - 0.5 = 3x - 1.5
# $$
#
# $$
# y = 3x - 1
# $$
#
# So, the equation of the tangent line to the curve $y = 4x^3$ at $x = 0.5$ is:
#
# $$
# y = 3x - 1
# $$
#
# ![image-2.png](attachment:image-2.png)
# ## Conclusion
#
# To find the equation of a tangent line to a curve at a particular point, we:
# 1. Find the derivative of the function.
# 2. Evaluate the derivative at the given point to find the slope.
# 3. Evaluate the function at the given point to find the coordinates of the point of tangency.
# 4. Use the point-slope form of the line to write the equation of the tangent line.
#
# These steps help us determine the equation of the tangent line that touches the curve at a specific point.

# %% [markdown]
# # Exercises: Finding Equations of Tangent Lines to Curves
#
# ## Exercise 1
#
# Find the equation of the tangent line to the curve $ y = 3x^{-3} $ at $ x = 2 $.
#
# Answer:
#    $$
#    y - \frac{3}{8} = -\frac{9}{16}(x - 2)
#    $$
#
# ## Exercise 2
#
# Find the equation of the tangent line to the curve $ y = 2x^2 - 2 $ at $ x = 1 $.
#
# Answer:
#    $$
#    y = 4x - 4
#    $$
#
# ## Exercise 3
#
# Find the equation of the tangent line to the curve $ y = \frac{4}{x^{1/2}} $ at $ x = 2 $.
#
# Answer:
#    $$
#    y - 2\sqrt{2} = -\frac{\sqrt{2}}{4}(x - 2)
#    $$
#
# ## Exercise 4
#
# Find the equation of the tangent line to the curve $ y = -3x^3 + 4 $ at $ x = 1 $.
#
# Answer:
#    $$
#    y - 1 = -9(x - 1)
#    $$
#
# ## Exercise 5
#
# Find the equation of the tangent line to the curve $ y = 5x^{2.5} $ at $ x = 1 $.
#
# Answer:
#
#    $$
#    y - 5 = 12.5(x - 1)
#    $$
#
# ## Solutions
#
# ### Solution 1: $ y = 3x^{-3} $ at $ x = 2 $
#
# 1. **Find the derivative**:
#
#    $$
#    f(x) = 3x^{-3}
#    $$
#
#    Using the power rule:
#
#    $$
#    f'(x) = 3 \cdot (-3)x^{-4} = -9x^{-4}
#    $$
#
# 2. **Evaluate the derivative at $ x = 2 $**:
#
#    $$
#    f'(2) = -9(2)^{-4} = -9 \cdot \frac{1}{16} = -\frac{9}{16}
#    $$
#
# 3. **Find the value of the function at $ x = 2 $**:
#
#    $$
#    f(2) = 3(2)^{-3} = 3 \cdot \frac{1}{8} = \frac{3}{8}
#    $$
#
#    The point of tangency is $ (2, \frac{3}{8}) $.
#
# 4. **Write the equation of the tangent line**:
#
#    Using the point-slope form:
#
#    $$
#    y - \frac{3}{8} = -\frac{9}{16}(x - 2)
#    $$
#
# ### Solution 2: $ y = 2x^2 - 2 $ at $ x = 1 $
#
# 1. **Find the derivative**:
#
#    $$
#    f(x) = 2x^2 - 2
#    $$
#
#    Using the power rule:
#
#    $$
#    f'(x) = 4x
#    $$
#
# 2. **Evaluate the derivative at $ x = 1 $**:
#
#    $$
#    f'(1) = 4 \cdot 1 = 4
#    $$
#
# 3. **Find the value of the function at $ x = 1 $**:
#
#    $$
#    f(1) = 2(1)^2 - 2 = 0
#    $$
#
#    The point of tangency is $ (1, 0) $.
#
# 4. **Write the equation of the tangent line**:
#
#    Using the point-slope form:
#
#    $$
#    y - 0 = 4(x - 1)
#    $$
#
#    Simplify:
#
#    $$
#    y = 4x - 4
#    $$
#
# ### Solution 3: $ y = \frac{4}{x^{1/2}} $ at $ x = 2 $
#
# 1. **Find the derivative**:
#
#    $$
#    f(x) = 4x^{-1/2}
#    $$
#
#    Using the power rule:
#
#    $$
#    f'(x) = 4 \cdot -\frac{1}{2}x^{-3/2} = -2x^{-3/2}
#    $$
#
# 2. **Evaluate the derivative at $ x = 2 $**:
#
#    $$
#    f'(2) = -2(2)^{-3/2} = -2 \cdot \frac{1}{2\sqrt{2}} = -\frac{1}{2\sqrt{2}} = -\frac{1}{2\sqrt{2}} \cdot \frac{\sqrt{2}}{\sqrt{2}} = -\frac{\sqrt{2}}{4}
#    $$
#
# 3. **Find the value of the function at $ x = 2 $**:
#
#    $$
#    f(2) = \frac{4}{2^{1/2}} = \frac{4}{\sqrt{2}} = 4 \cdot \frac{\sqrt{2}}{2} = 2\sqrt{2}
#    $$
#
#    The point of tangency is $ (2, 2\sqrt{2}) $.
#
# 4. **Write the equation of the tangent line**:
#
#    Using the point-slope form:
#
#    $$
#    y - 2\sqrt{2} = -\frac{\sqrt{2}}{4}(x - 2)
#    $$
#
# ### Solution 4: $ y = -3x^3 + 4 $ at $ x = 1 $
#
# 1. **Find the derivative**:
#
#    $$
#    f(x) = -3x^3 + 4
#    $$
#
#    Using the power rule:
#
#    $$
#    f'(x) = -9x^2
#    $$
#
# 2. **Evaluate the derivative at $ x = 1 $**:
#
#    $$
#    f'(1) = -9(1)^2 = -9
#    $$
#
# 3. **Find the value of the function at $ x = 1 $**:
#
#    $$
#    f(1) = -3(1)^3 + 4 = 1
#    $$
#
#    The point of tangency is $ (1, 1) $.
#
# 4. **Write the equation of the tangent line**:
#
#    Using the point-slope form:
#
#    $$
#    y - 1 = -9(x - 1)
#    $$
#
# ### Solution 5: $ y = 5x^{2.5} $ at $ x = 1 $
#
# 1. **Find the derivative**:
#
#    $$
#    f(x) = 5x^{2.5}
#    $$
#
#    Using the power rule:
#
#    $$
#    f'(x) = 5 \cdot 2.5x^{1.5} = 12.5x^{1.5}
#    $$
#
# 2. **Evaluate the derivative at $ x = 1 $**:
#
#    $$
#    f'(1) = 12.5(1)^{1.5} = 12.5
#    $$
#
# 3. **Find the value of the function at $ x = 1 $**:
#
#    $$
#    f(1) = 5(1)^{2.5} = 5
#    $$
#
#    The point of tangency is $ (1, 5) $.
#
# 4. **Write the equation of the tangent line**:
#
#    Using the point-slope form:
#
#    $$
#    y - 5 = 12.5(x - 1)
#    $$
